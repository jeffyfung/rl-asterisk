# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Plot the reward over episodes
epi_len_over_all_episodes = np.load("data/epi_len_over_all_episodes.npy")
rtns_over_all_episodes = np.load("data/rtns_over_all_episodes.npy")

# %%
plt.plot(epi_len_over_all_episodes)
plt.xlabel("Episodes")
plt.ylabel("Episodes Length")
# Out:
# Text(0, 0.5, 'Episodes Length')

# %%
plt.plot(rtns_over_all_episodes)
plt.xlabel("Episodes")
plt.ylabel("Returns")
# Out:
# Text(0, 0.5, 'Returns')
